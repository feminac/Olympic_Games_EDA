# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
olympic=pd.read_csv(r'C:\Users\femif\Downloads\olympic_games.csv')
olympic
# Out:
#       year games_type host_country host_city  athletes  teams  competitions  \
# 0     2022     Winter        China   Beijing      2834     91           109
# 1     2022     Winter        China   Beijing      2834     91           109
# 2     2022     Winter        China   Beijing      2834     91           109
# 3     2022     Winter        China   Beijing      2834     91           109
# 4     2022     Winter        China   Beijing      2834     91           109
# ...    ...        ...          ...       ...       ...    ...           ...
# 1776  1896     Summer       Greece    Athens       241     14            43
# 1777  1896     Summer       Greece    Athens       241     14            43
# 1778  1896     Summer       Greece    Athens       241     14            43
# 1779  1896     Summer       Greece    Athens       241     14            43
# 1780  1896     Summer       Greece    Athens       241     14            43
#
#                        country  gold  silver  bronze
# 0                    Australia     1       2       1
# 1                      Austria     7       7       4
# 2                      Belarus     0       2       0
# 3                      Belgium     1       0       1
# 4                       Canada     4       8      14
# ...                        ...   ...     ...     ...
# 1776                   Hungary     2       1       3
# 1777                Mixed team     1       0       1
# 1778               Switzerland     1       2       0
# 1779            United Kingdom     3       3       3
# 1780  United States of America    11       7       2
#
# [1781 rows x 11 columns]

# %%
olympic.shape
# Out:
# (1781, 11)

# %%
olympic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1781 entries, 0 to 1780
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          1781 non-null   int64
#  1   games_type    1781 non-null   object
#  2   host_country  1781 non-null   object
#  3   host_city     1781 non-null   object
#  4   athletes      1781 non-null   int64
#  5   teams         1781 non-null   int64
#  6   competitions  1781 non-null   int64
#  7   country       1781 non-null   object
#  8   gold          1781 non-null   int64
#  9   silver        1781 non-null   int64
#  10  bronze        1781 non-null   int64
# dtypes: int64(7), object(4)
# memory usage: 153.2+ KB

# %%
olympic.columns
# Out:
# Index(['year', 'games_type', 'host_country', 'host_city', 'athletes', 'teams',
#        'competitions', 'country', 'gold', 'silver', 'bronze'],
#       dtype='object')

# %% [markdown]
# # Data testing and cleaning

# %%
olympic.isnull().sum()
# Out:
# year            0
# games_type      0
# host_country    0
# host_city       0
# athletes        0
# teams           0
# competitions    0
# country         0
# gold            0
# silver          0
# bronze          0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# Which country and city have hosted the most Olympic Games?

# %%
host_countries_count = olympic["host_country"].value_counts().sort_values(ascending=False)
top_5_countries = host_countries_count.head()
print(top_5_countries)
# Out:
# United States    234
# Japan            175
# Great Britain    143
# China            116
# France            90
# Name: host_country, dtype: int64

# %%
host_cities_count = olympic["host_city"].value_counts().sort_values(ascending=False)
top_5_cities = host_cities_count.head()
print(top_5_cities)
# Out:
# London     143
# Tokyo      134
# Beijing    116
# Rio         86
# Athens      85
# Name: host_city, dtype: int64

# %%
plt.figure(figsize = (12,8))
plt.pie(x = top_5_countries.values, labels = top_5_countries.index, autopct='%1.1f%%')

plt.title("Top 5 host countries", fontweight = 'bold')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (12,8))
plt.pie(x = top_5_cities.values, labels = top_5_cities.index, autopct='%1.1f%%')

plt.title("Top 5 host cities", fontweight = 'bold')


plt.tight_layout()
plt.show()

# %%
def bar_plot(_x,_y,xlabel,ylabel,title):
    plt.figure(figsize = (12,8))
    sns.set(style="whitegrid")  

    sns.barplot(x=_x, y=_y, palette="crest")
    
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)

    plt.xticks(rotation=90)

# %%
bar_plot(host_countries_count.index, 
         host_countries_count.values, 
         xlabel="Countries",
         ylabel="Games",
         title="All host countries sorted by the number of games")

# %%
bar_plot(host_cities_count.index, 
         host_cities_count.values, 
         xlabel="Cities",
         ylabel="Games",
         title="All host cities sorted by the number of games")

# %%
olympic['games_type'].value_counts()
# Out:
# Summer    1339
# Winter     442
# Name: games_type, dtype: int64

# %%
olympic['games_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
olympic[['gold','silver']].sum()
# Out:
# gold      6674
# silver    6631
# dtype: int64
